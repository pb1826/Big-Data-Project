# %%
from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import os
import pandas as pd
import seaborn as sns
import time
plt.style.use('ggplot')

# %matplotlib inline

# %%
#bronx
bronx = pd.read_csv("bronx.csv",names=['YEAR','COUNT'])
#removing headers
bronx = bronx.loc[1:]
bronx

#brooklyn
brooklyn = pd.read_csv("brooklyn.csv",names=['YEAR','COUNT'])
#removing headers
brooklyn = brooklyn.loc[1:]
brooklyn

#manhattan
manhattan = pd.read_csv("manhattan.csv",names=['YEAR','COUNT'])
#removing headers
manhattan= manhattan.loc[1:]
manhattan

#queens
queens = pd.read_csv("queens.csv",names=['YEAR','COUNT'])
#removing headers
queens = queens.loc[1:]
queens

#staten

staten = pd.read_csv("bronx.csv",names=['YEAR','COUNT'])
#removing headers
staten = staten.loc[1:]
staten
# Out:
#       YEAR  COUNT
# 1     2006      6
# 2     2006      8
# 3     2006      7
# 4     2006     10
# 5     2006     17
# 6     2006      3
# 7     2006     14
# 8     2006      2
# 9     2006      3
# 10    2006      2
# 11    2006     12
# 12    2006      4
# 13    2006      2
# 14    2006      9
# 15    2006      2
# 16    2006      7
# 17    2006     28
# 18    2006     11
# 19    2006      4
# 20    2006     50
# 21    2006     31
# 22    2006      3
# 23    2006      4
# 24    2006     16
# 25    2006     11
# 26    2006      1
# 27    2006     10
# 28    2006      1
# 29    2006     26
# 30    2006      2
# ...    ...    ...
# 8579  2015      9
# 8580  2015      2
# 8581  2015     17
# 8582  2015      1
# 8583  2015      1
# 8584  2015      1
# 8585  2015      4
# 8586  2015      9
# 8587  2015      1
# 8588  2015      3
# 8589  2015      2
# 8590  2015      3
# 8591  2015     18
# 8592  2015      8
# 8593  2015      3
# 8594  2015     28
# 8595  2015     44
# 8596  2015      2
# ...

# %%
import bokeh.io, bokeh.plotting, bokeh.models
from bokeh.models import DatetimeTickFormatter
bokeh.io.output_notebook()
from bokeh.layouts import gridplot
from bokeh.plotting import figure, show, output_file

p1 = figure(x_axis_type="linear", title=" NYC weather feb data from 2005-2016")
p1.grid.grid_line_alpha=0.3
p1.xaxis.axis_label = 'Year'
p1.yaxis.axis_label = 'Count of total crime'
p1.xaxis[0].ticker.desired_num_ticks = 11 #adjust the number of ticks for time axis

p1.line(bronx['YEAR'], bronx['COUNT'], color='#FF0000',line_width = 3)

show(p1)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ffb6da17-d37e-4fa2-97e3-271a6311534b">Loading BokehJS ...</span>
#     </div>
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 8608), ('y', 8986)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="14ee34cf-dfed-4883-a58a-f502a25e36f0"></div>
# </div>
