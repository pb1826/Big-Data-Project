# %%
#matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime as dt
from IPython.display import display
import folium

# %matplotlib inline
plt.style.use('ggplot')

# %%
#halloween

#load csv
cleaned = pd.read_csv("overall-crime.csv", header=None)
length = cleaned.count
cleaned.columns = ['LAT','LON','COUNT']

cleaned=cleaned.head(100000)

# cleaned['COUNT']=cleaned.groupby(['LAT','LON'])['LAT','LON'].transform('count')
# cleaned=cleaned.drop_duplicates()
NYC_COORDINATES=[40.8448, -73.8648]
# create empty map zoomed in on San Francisco
map = folium.Map(location=NYC_COORDINATES, zoom_start=12)

# add a marker for every record in the filtered data, use a clustered view
cleaned.apply(lambda row:folium.Marker(location=[row["LAT"], row["LON"]]).add_to(map),axis = 1)
map
# display(map)

# for each in cleaned[0:length].iterrows():
#   map.CircleMarker(
#       location = (each['LAT'],each['LON']),
#       clustered_marker = True).add_to(map)

# display(map)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-39436d8a2d42> in <module>()
#      15
#      16 # add a marker for every record in the filtered data, use a clustered view
# ---> 17 cleaned.apply(lambda row:folium.Marker(location=[row["LAT"], row["LON"]]).add_to(map),axis = 1)
#      18 map
#      19 # display(map)
#
# c:\users\ninayar\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4260                         f, axis,
#    4261                         reduce=reduce,
# -> 4262                         ignore_failures=ignore_failures)
#    4263             else:
#    4264                 return self._apply_broadcast(f, axis)
#
# ...
