# %%
from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import os
import pandas as pd
import seaborn as sns
import time
import bokeh.io, bokeh.plotting, bokeh.models
from bokeh.models import DatetimeTickFormatter
bokeh.io.output_notebook()
from bokeh.layouts import gridplot
from bokeh.plotting import figure, show, output_file
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, DataRange1d, PanTool, WheelZoomTool, BoxSelectTool
)
from bokeh.resources import CDN
from bokeh.embed import components, autoload_static, autoload_server
import folium


# %matplotlib inline
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6e97392f-1b9c-490f-83f4-61769de45621">Loading BokehJS ...</span>
#     </div>

# %%
bronx = pd.read_csv("locationplot/bronx-assault-all.csv", names = ["lat","long"])
bronx["lat"] = bronx["lat"].str.replace("(","")
bronx["long"] = bronx["long"].str.replace(")","")
bronx['lat'] = bronx['lat'].astype(float)
bronx['long'] = bronx['long'].astype(float)
# get the coordinates with the most incidents of assault in bronx
new =  pd.core.frame.DataFrame({'count' : bronx.groupby(["lat", "long"] ).size()}).reset_index().sort_values('count',ascending = False)
new['index'] = new.index
new = new.head(50)
map = folium.Map(location=[40.8448, -73.8648], zoom_start=13)
new.apply(lambda row:folium.Marker(location=[row["lat"], row["long"]]).add_to(map),axis = 1)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Brooklyn

# %%
brooklyn = pd.read_csv("locationplot/brooklyn-assault-feb.csv", names = ["lat","long"])
brooklyn["lat"] = brooklyn["lat"].str.replace("(","")
brooklyn["long"] = brooklyn["long"].str.replace(")","")
brooklyn['lat'] = brooklyn['lat'].astype(float)
brooklyn['long'] = brooklyn['long'].astype(float)
# get the coordinates with the most incidents of assault in bronx
new_df =  pd.core.frame.DataFrame({'count' : df_brooklyn_assault_feb.groupby(["lat", "long"] ).size()}).reset_index().sort_values('count',ascending = False)
new_df['index'] = new_df.index

new_df = new_df.head(50)
map = folium.Map(location=[40.6782, -73.9442], zoom_start=13)
new_df.apply(lambda row:folium.Marker(location=[row["lat"], row["long"]]).add_to(map),axis = 1)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Manhattan

# %%
manhattan = pd.read_csv("locationplot/manhattan-larceny-feb.csv", names = ["lat","long"])
manhattan["lat"] = manhattan["lat"].str.replace("(","")
manhattan["long"] = manhattan["long"].str.replace(")","")
manhattan['lat'] = manhattan['lat'].astype(float)
manhattan['long'] = manhattan['long'].astype(float)
# get the coordinates with the most incidents of assault in bronx
new_df =  pd.core.frame.DataFrame({'count' : df_manhattan_larceny_feb.groupby(["lat", "long"] ).size()}).reset_index().sort_values('count',ascending = False)
new_df['index'] = new_df.index

new_df = new_df.head(10)
map = folium.Map(location=[40.7831, -73.9712], zoom_start=13)
new_df.apply(lambda row:folium.Marker(location=[row["lat"], row["long"]]).add_to(map),axis = 1)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Queens

# %%
queens = pd.read_csv("locationplot/queens-larceny-feb.csv", names = ["lat","long"])
queens["lat"] = queens["lat"].str.replace("(","")
queens["long"] = queens["long"].str.replace(")","")
queens['lat'] = queens['lat'].astype(float)
queens['long'] = queens['long'].astype(float)
# get the coordinates with the most incidents of assault in bronx
new_df =  pd.core.frame.DataFrame({'count' : df_queens_larceny_feb.groupby(["lat", "long"] ).size()}).reset_index().sort_values('count',ascending = False)
new_df['index'] = new_df.index

new_df = new_df.head(50)
map = folium.Map(location=[40.7282, -73.7949], zoom_start=13)
new_df.apply(lambda row:folium.Marker(location=[row["lat"], row["long"]]).add_to(map),axis = 1)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Staten Island

# %%
staten = pd.read_csv("locationplot/staten-assault-feb.csv", names = ["lat","long"])
staten["lat"] = staten["lat"].str.replace("(","")
staten["long"] = staten["long"].str.replace(")","")
staten['lat'] = staten['lat'].astype(float)
staten['long'] = staten['long'].astype(float)
# get the coordinates with the most incidents of assault in bronx
new_df =  pd.core.frame.DataFrame({'count' : df_si_feb.groupby(["lat", "long"] ).size()}).reset_index().sort_values('count',ascending = False)
new_df['index'] = new_df.index

new_df = new_df.head(10)
map = folium.Map(location=[40.5795, -74.1502], zoom_start=13)
new_df.apply(lambda row:folium.Marker(location=[row["lat"], row["long"]]).add_to(map),axis = 1)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
