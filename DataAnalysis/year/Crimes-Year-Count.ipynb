# %%
#matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import *
from IPython.display import display
# %matplotlib inline
plt.style.use('ggplot')

#YEAR limits
max=datetime.strptime('01/01/2006', "%m/%d/%Y").strftime('%m/%d/%Y')
min=datetime.strptime('01/01/2017', "%m/%d/%Y").strftime('%m/%d/%Y')
#oflist=['PETIT LARCENY','HARRASSMENT 2','ASSAULT 3 & RELATED OFFENSES','CRIMINAL MISCHIEF & RELATED OF','GRAND LARCENY','OFF. AGNST PUB ORD SENSBLTY &','DANGEROUS DRUGS','ROBBERY','BURGLARY','FELONY ASSAULT']
#load csv
overall = pd.read_csv("overall-crime.csv", header=None,)
overall.columns = ['YEAR','COUNT']
#overall['OFNS_DESC']=overall['OFNS_DESC'].str.strip()
#overall=overall[overall['OFNS_DESC'].isin(oflist)] #ofsc list

bronx = pd.read_csv("bronx-crime.csv", header=None,)
bronx.columns = ['YEAR','COUNT']
#bronx['OFNS_DESC']=bronx['OFNS_DESC'].str.strip()
#bronx=bronx[bronx['OFNS_DESC'].isin(oflist)]


brooklyn = pd.read_csv("brooklyn-crime.csv", header=None,)
brooklyn.columns = ['YEAR','COUNT']
#brooklyn['OFNS_DESC']=brooklyn['OFNS_DESC'].str.strip()
#brooklyn=brooklyn[brooklyn['OFNS_DESC'].isin(oflist)] #ofsc list

manhattan = pd.read_csv("manhattan-crime.csv", header=None,)
manhattan.columns = ['YEAR','COUNT']
#manhattan['OFNS_DESC']=manhattan['OFNS_DESC'].str.strip()
#manhattan=manhattan[manhattan['OFNS_DESC'].isin(oflist)] #ofsc list

staten = pd.read_csv("staten-crime.csv", header=None,)
staten.columns = ['YEAR','COUNT']
#staten['OFNS_DESC']=staten['OFNS_DESC'].str.strip()
#staten=staten[staten['OFNS_DESC'].isin(oflist)] #ofsc list

queens = pd.read_csv("queens-crime.csv", header=None,)
queens.columns = ['YEAR','COUNT']
#queens['OFNS_DESC']=queens['OFNS_DESC'].str.strip()
#queens=queens[queens['OFNS_DESC'].isin(oflist)] #ofsc list

# %%
#kycd & ofnc top 10 
overall=overall.sort_values(by='COUNT', ascending=False)
# overall = overall.head(12)
overall.to_csv('top-overall-YEAR.csv')

#staten
staten = staten.sort_values(by='COUNT', ascending=False)
# staten=staten.head(12)
staten.to_csv('top-staten-YEAR.csv')

#bronx
bronx = bronx.sort_values(by='COUNT', ascending=False)
# bronx=bronx.head(12)
bronx.to_csv('top-bronx-YEAR.csv')

#brooklyn
brooklyn = brooklyn.sort_values(by='COUNT', ascending=False)
# brooklyn=brooklyn.head(12)
brooklyn.to_csv('top-brooklyn-YEAR.csv')

#manhttan
manhattan=manhattan.sort_values(by='COUNT', ascending=False)
# manhattan=manhattan.head(12)
manhattan.to_csv('top-manhattan-YEAR.csv')

#queens
queens=queens.sort_values(by='COUNT', ascending=False)
# queens=queens.head(12)
queens.to_csv('top-queens-YEAR.csv')

# %%
#overall
#pivot_overall = overall.pivot(index='YEAR', columns='OFNS_DESC', values='COUNT')
pivot_overall = overall.set_index('YEAR')
pivot_overall.plot(kind='bar',stacked=True,)
#plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8), title='OFNS_DESC')
plt.legend(loc='upper right', bbox_to_anchor=(1.7, 0.8), title='COUNT')
plt.title("Crimes by the YEAR")
plt.xlabel('YEAR')
plt.ylabel('COUNT')
plt.savefig("overall-crime-YEAR-only.png",bbox_inches='tight')

# %%
#bronx
#pivot_bronx = bronx.pivot(index='YEAR', columns='OFNS_DESC', values='COUNT')
pivot_bronx = bronx.set_index('YEAR')
pivot_bronx.plot(kind='bar',stacked=True,)
#plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8), title='OFNS_DESC')
plt.legend(loc='upper right', bbox_to_anchor=(1.7, 0.8), title='COUNT')
plt.title("Crimes by the YEAR - Bronx")
plt.xlabel('YEAR')
plt.ylabel('COUNT')
plt.savefig("bronx-crime-YEAR-only.png",bbox_inches='tight')

# %%
#brooklyn
#pivot_brooklyn= brooklyn.pivot(index='YEAR', columns='OFNS_DESC', values='COUNT')
pivot_brooklyn= brooklyn.set_index('YEAR')
pivot_brooklyn.plot(kind='bar',stacked=True,)
#plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8), title='OFNS_DESC')
plt.legend(loc='upper right', bbox_to_anchor=(1.7, 0.8), title='COUNT')
plt.title("Crimes by the YEAR - Brooklyn")
plt.xlabel('YEAR')
plt.ylabel('COUNT')
plt.savefig("brooklyn-crime-YEAR.png",bbox_inches='tight')

# %%
#manhattan
#pivot_manhattan= manhattan.pivot(index='YEAR', columns='OFNS_DESC', values='COUNT')
pivot_manhattan= manhattan.set_index('YEAR')
pivot_manhattan.plot(kind='bar',stacked=True,)
#plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8), title='OFNS_DESC')
plt.legend(loc='upper right', bbox_to_anchor=(1.7, 0.8), title='COUNT')
plt.title("Crimes by the YEAR - Manhattan")
plt.xlabel('YEAR')
plt.ylabel('COUNT')
plt.savefig("manhattan-crime-YEAR.png",bbox_inches='tight')

# %%
#queens
#pivot_queens= queens.pivot(index='YEAR', columns='OFNS_DESC', values='COUNT')
pivot_queens= queens.set_index('YEAR')
pivot_queens.plot(kind='bar',stacked=True,)
#plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8), title='OFNS_DESC')
plt.legend(loc='upper right', bbox_to_anchor=(1.7, 0.8), title='COUNT')
plt.title("Crimes by the YEAR - Queens")
plt.xlabel('YEAR')
plt.ylabel('COUNT')
plt.savefig("queens-crime-YEAR.png",bbox_inches='tight')

# %%
#staten
#pivot_staten= staten.pivot(index='YEAR', columns='OFNS_DESC', values='COUNT')
pivot_staten= staten.set_index('YEAR')
pivot_staten.plot(kind='bar',stacked=True,)
#plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8), title='OFNS_DESC')
plt.legend(loc='upper right', bbox_to_anchor=(1.7, 0.8), title='COUNT')
plt.title("Crimes by the YEAR - Staten")
plt.xlabel('YEAR')
plt.ylabel('COUNT')
plt.savefig("staten-crime-YEAR.png",bbox_inches='tight')
