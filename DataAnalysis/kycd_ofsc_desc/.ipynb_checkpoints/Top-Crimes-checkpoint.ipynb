# %%
#matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display
# %matplotlib inline
plt.style.use('ggplot')


#load csv
overall = pd.read_csv("overall-crime.csv", header=None,)
overall.columns = ['KY_CD', 'OFNS_DESC', 'COUNT']
bronx = pd.read_csv("bronx-crime.csv", header=None,)
bronx.columns = ['KY_CD', 'OFNS_DESC', 'COUNT']

brooklyn = pd.read_csv("brooklyn-crime.csv", header=None,)
brooklyn.columns = ['KY_CD', 'OFNS_DESC', 'COUNT']

manhattan = pd.read_csv("manhattan-crime.csv", header=None,)
manhattan.columns = ['KY_CD', 'OFNS_DESC', 'COUNT']

staten = pd.read_csv("staten-crime.csv", header=None,)
staten.columns = ['KY_CD', 'OFNS_DESC', 'COUNT']

queens = pd.read_csv("queens-crime.csv", header=None,)
queens.columns = ['KY_CD', 'OFNS_DESC', 'COUNT']

# %%
#kycd & ofnc top 10 
overall=overall.sort_values(by='COUNT', ascending=False)
overall = overall.head(11)
overall.to_csv('top-overall.csv')

# %%
#staten
staten = staten.sort_values(by='COUNT', ascending=False)
staten=staten.head(11)
staten.to_csv('top-staten.csv')

# %%
#bronx
bronx = bronx.sort_values(by='COUNT', ascending=False)
bronx=bronx.head(11)
bronx.to_csv('top-bronx.csv')

# %%
#brooklyn
brooklyn = brooklyn.sort_values(by='COUNT', ascending=False)
brooklyn=brooklyn.head(11)
brooklyn.to_csv('top-brooklyn.csv')

# %%
#manhttan
manhattan=manhattan.sort_values(by='COUNT', ascending=False)
manhattan=manhattan.head(11)
manhattan.to_csv('top-manhattan.csv')

# %%
#queens
queens=queens.sort_values(by='COUNT', ascending=False)
queens=queens.head(11)
queens.to_csv('top-queens.csv')

# %%
#overall
pivot_overall = overall.pivot(index='OFNS_DESC', columns='KY_CD', values='COUNT')
pivot_overall.plot(kind='bar',stacked=True,)
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8), title='KY_CD')
plt.title("Top 10 Crimes in NYC")
plt.xlabel('OFNS_DSC')
plt.ylabel('COUNT')
plt.savefig("overall-crime.png",bbox_inches='tight')

# %%
#bronx
pivot_bronx = bronx.pivot(index='OFNS_DESC', columns='KY_CD', values='COUNT')
pivot_bronx.plot(kind='bar',stacked=True,)
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8), title='KY_CD')
plt.title("Top 10 Crimes in Bronx")
plt.xlabel('OFNS_DSC')
plt.ylabel('COUNT')
plt.savefig("bronx-crime.png",bbox_inches='tight')

# %%
#brooklyn
pivot_brooklyn = brooklyn.pivot(index='OFNS_DESC', columns='KY_CD', values='COUNT')
pivot_brooklyn.plot(kind='bar',stacked=True,)
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8), title='KY_CD')
plt.title("Top 10 Crimes in Brooklyn")
plt.xlabel('OFNS_DSC')
plt.ylabel('COUNT')
plt.savefig("brooklyn-crime.png",bbox_inches='tight')

# %%
#manhattan
pivot_manhattan = manhattan.pivot(index='OFNS_DESC', columns='KY_CD', values='COUNT')
pivot_manhattan.plot(kind='bar',stacked=True,)
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8), title='KY_CD')
plt.title("Top 10 Crimes in Manhattan")
plt.xlabel('OFNS_DSC')
plt.ylabel('COUNT')
plt.savefig("manhattan-crime.png",bbox_inches='tight')

# %%
#queens
pivot_queens = queens.pivot(index='OFNS_DESC', columns='KY_CD', values='COUNT')
pivot_queens.plot(kind='bar',stacked=True,)
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8), title='KY_CD')
plt.title("Top 10 Crimes in Queens")
plt.xlabel('OFNS_DSC')
plt.ylabel('COUNT')
plt.savefig("queens-crime.png",bbox_inches='tight')

# %%
#staten
pivot_staten = staten.pivot(index='OFNS_DESC', columns='KY_CD', values='COUNT')
pivot_staten.plot(kind='bar',stacked=True,)
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8), title='KY_CD')
plt.title("Top 10 Crimes in Staten Island")
plt.xlabel('OFNS_DSC')
plt.ylabel('COUNT')
plt.savefig("staten-crime.png",bbox_inches='tight')
