# %%
#matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display
# %matplotlib inline
plt.style.use('ggplot')


#load csv
overall = pd.read_csv("overall-crime.csv", header=None,)
overall.columns = ['HADEVELOPT', 'COUNT']
overall=overall[overall['HADEVELOPT'].notnull()] #pandas interprets NA by default as nulll

bronx = pd.read_csv("bronx-crime.csv", header=None,)
bronx.columns = ['HADEVELOPT', 'COUNT']
bronx=bronx[bronx['HADEVELOPT'].notnull()] #pandas interprets NA by default as nulll

brooklyn = pd.read_csv("brooklyn-crime.csv", header=None,)
brooklyn.columns = ['HADEVELOPT', 'COUNT']
brooklyn=brooklyn[brooklyn['HADEVELOPT'].notnull()] #pandas interprets NA by default as nulll

manhattan = pd.read_csv("manhattan-crime.csv", header=None,)
manhattan.columns = ['HADEVELOPT', 'COUNT']
manhattan=manhattan[manhattan['HADEVELOPT'].notnull()] #pandas interprets NA by default as nulll

staten = pd.read_csv("staten-crime.csv", header=None,)
staten.columns = ['HADEVELOPT', 'COUNT']
staten=staten[staten['HADEVELOPT'].notnull()] #pandas interprets NA by default as nulll

queens = pd.read_csv("queens-crime.csv", header=None,)
queens.columns = ['HADEVELOPT', 'COUNT']
queens=queens[queens['HADEVELOPT'].notnull()] #pandas interprets NA by default as nulll

# %%
#kycd & ofnc top 10 
overall=overall.sort_values(by='COUNT', ascending=False)
overall = overall.head(10)
overall.to_csv('bottom-overall.csv')

# %%
#staten
staten = staten.sort_values(by='COUNT', ascending=False)
staten=staten.head(10)
staten.to_csv('bottom-staten.csv')

# %%
#bronx
bronx = bronx.sort_values(by='COUNT', ascending=False)
bronx=bronx.head(10)
bronx.to_csv('bottom-bronx.csv')

# %%
#brooklyn
brooklyn = brooklyn.sort_values(by='COUNT', ascending=False)
brooklyn=brooklyn.head(10)
brooklyn.to_csv('bottom-brooklyn.csv')

# %%
#manhttan
manhattan=manhattan.sort_values(by='COUNT', ascending=False)
manhattan=manhattan.head(10)
manhattan.to_csv('bottom-manhattan.csv')

# %%
#queens
queens=queens.sort_values(by='COUNT', ascending=False)
queens=queens.head(10)
queens.to_csv('bottom-queens.csv')

# %%
#overall
#pivot_overall = overall.pivot(index='OFNS_DESC', columns='KY_CD', values='COUNT')
pivot_overall = overall.set_index('HADEVELOPT')
pivot_overall.plot(kind='bar',stacked=True,)
#plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8), title='KY_CD')
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8))
plt.title("Top 10 Areas in NYC with Lowest Number of Crimes")
plt.xlabel('HADEVELOPT')
plt.ylabel('COUNT')
plt.savefig("safe-overall-crime-hav.png",bbox_inches='tight')

# %%
#bronx
#pivot_bronx = bronx.pivot(index='OFNS_DESC', columns='KY_CD', values='COUNT')
pivot_bronx = bronx.set_index('HADEVELOPT')
pivot_bronx.plot(kind='bar',stacked=True,)
#plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8), title='KY_CD')
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8))
plt.title("Top 10 Areas in Bronx with Lowest Number of Crimes")
plt.xlabel('HADEVELOPT')
plt.ylabel('COUNT')
plt.savefig("safe-bronx-crime-hav.png",bbox_inches='tight')

# %%
#brooklyn
#pivot_brooklyn = brooklyn.pivot(index='OFNS_DESC', columns='KY_CD', values='COUNT')
pivot_brooklyn = brooklyn.set_index('HADEVELOPT')
pivot_brooklyn.plot(kind='bar',stacked=True,)
#plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8), title='KY_CD')
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8))
plt.title("Top 10 Areas in brooklyn with Lowest Number of Crimes")
plt.xlabel('HADEVELOPT')
plt.ylabel('COUNT')
plt.savefig("safe-brooklyn-crime-hav.png",bbox_inches='tight')

# %%
#manhattan
#pivot_manhattan = manhattan.pivot(index='OFNS_DESC', columns='KY_CD', values='COUNT')
pivot_manhattan = manhattan.set_index('HADEVELOPT')
pivot_manhattan.plot(kind='bar',stacked=True,)
#plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8), title='KY_CD')
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8))
plt.title("Top 10 Areas in manhattan with Lowest Number of Crimes")
plt.xlabel('HADEVELOPT')
plt.ylabel('COUNT')
plt.savefig("safe-manhattan-crime-hav.png",bbox_inches='tight')

# %%
#queens
#pivot_queens = queens.pivot(index='OFNS_DESC', columns='KY_CD', values='COUNT')
pivot_queens = queens.set_index('HADEVELOPT')
pivot_queens.plot(kind='bar',stacked=True,)
#plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8), title='KY_CD')
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8))
plt.title("Top 10 Areas in queens with Lowest Number of Crimes")
plt.xlabel('HADEVELOPT')
plt.ylabel('COUNT')
plt.savefig("safe-queens-crime-hav.png",bbox_inches='tight')

# %%
#staten
#pivot_staten = staten.pivot(index='OFNS_DESC', columns='KY_CD', values='COUNT')
pivot_staten = staten.set_index('HADEVELOPT')
pivot_staten.plot(kind='bar',stacked=True,)
#plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8), title='KY_CD')
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8))
plt.title("Top 10 Areas in staten with Lowest Number of Crimes")
plt.xlabel('HADEVELOPT')
plt.ylabel('COUNT')
plt.savefig("safe-staten-crime-hav.png",bbox_inches='tight')
