# %%
#matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import *
from IPython.display import display
# %matplotlib inline
plt.style.use('ggplot')

#MONTH limits
max=datetime.strptime('01/01/2006', "%m/%d/%Y").strftime('%m/%d/%Y')
min=datetime.strptime('01/01/2017', "%m/%d/%Y").strftime('%m/%d/%Y')
oflist=['KIDNAPPING AND RELATED OFFENSES','OFFENSES AGAINST MARRIAGE UNCL','UNDER THE INFLUENCE OF DRUGS','ABORTION','OTHER STATE LAWS NON PENAL LAW','KIDNAPPING','OTHER TRAFFIC INFRACTION','FORTUNE TELLING','LOITERING','LOITERING/DEVIATE SEX']
#load csv
overall = pd.read_csv("overall-crime.csv", header=None,)
overall.columns = ['MONTH','OFNS_DESC','COUNT']
overall['OFNS_DESC']=overall['OFNS_DESC'].str.strip()
overall=overall[overall['OFNS_DESC'].isin(oflist)] #ofsc list

bronx = pd.read_csv("bronx-crime.csv", header=None,)
bronx.columns = ['MONTH','OFNS_DESC','COUNT']
bronx['OFNS_DESC']=bronx['OFNS_DESC'].str.strip()
bronx=bronx[bronx['OFNS_DESC'].isin(oflist)]

brooklyn = pd.read_csv("brooklyn-crime.csv", header=None,)
brooklyn.columns = ['MONTH','OFNS_DESC','COUNT']
brooklyn['OFNS_DESC']=brooklyn['OFNS_DESC'].str.strip()
brooklyn=brooklyn[brooklyn['OFNS_DESC'].isin(oflist)] #ofsc list

manhattan = pd.read_csv("manhattan-crime.csv", header=None,)
manhattan.columns = ['MONTH','OFNS_DESC','COUNT']
manhattan['OFNS_DESC']=manhattan['OFNS_DESC'].str.strip()
manhattan=manhattan[manhattan['OFNS_DESC'].isin(oflist)] #ofsc list

staten = pd.read_csv("staten-crime.csv", header=None,)
staten.columns = ['MONTH','OFNS_DESC','COUNT']
staten['OFNS_DESC']=staten['OFNS_DESC'].str.strip()
staten=staten[staten['OFNS_DESC'].isin(oflist)] #ofsc list

queens = pd.read_csv("queens-crime.csv", header=None,)
queens.columns = ['MONTH','OFNS_DESC','COUNT']
queens['OFNS_DESC']=queens['OFNS_DESC'].str.strip()
queens=queens[queens['OFNS_DESC'].isin(oflist)] #ofsc list

# %%
#kycd & ofnc bottom 10 
overall=overall.sort_values(by='COUNT')
#overall = overall.head(10)
overall.to_csv('bottom-overall.csv')

#staten
staten = staten.sort_values(by='COUNT')
#staten=staten.head(10)
staten.to_csv('bottom-staten.csv')

#bronx
bronx = bronx.sort_values(by='COUNT')
#bronx=bronx.head(10)
bronx.to_csv('bottom-bronx.csv')

#brooklyn
brooklyn = brooklyn.sort_values(by='COUNT')
#brooklyn=brooklyn.head(10)
brooklyn.to_csv('bottom-brooklyn.csv')

#manhttan
manhattan=manhattan.sort_values(by='COUNT')
#manhattan=manhattan.head(10)
manhattan.to_csv('bottom-manhattan.csv')

#queens
queens=queens.sort_values(by='COUNT')
#queens=queens.head(10)
queens.to_csv('bottom-queens.csv')

# %%
#overall
pivot_overall = overall.pivot(index='MONTH', columns='OFNS_DESC', values='COUNT')
#pivot_overall = overall.set_index('HADEVELOPT')
pivot_overall.plot(kind='bar',stacked=True,)
#plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8), title='OFNS_DESC')
plt.legend(loc='upper right', bbox_to_anchor=(1.7, 0.8), title='OFNS_DESC')
plt.title("Months at which Crimes were Lowest")
plt.xlabel('MONTH')
plt.ylabel('COUNT')
plt.savefig("overall-crime-month-low.png",bbox_inches='tight')

# %%
#bronx
pivot_bronx = bronx.pivot(index='MONTH', columns='OFNS_DESC', values='COUNT')
#pivot_bronx = bronx.set_index('HADEVELOPT')
pivot_bronx.plot(kind='bar',stacked=True,)
#plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8), title='OFNS_DESC')
plt.legend(loc='upper right', bbox_to_anchor=(1.7, 0.8), title='OFNS_DESC')
plt.title("Months at which Crimes were Lowest")
plt.xlabel('MONTH')
plt.ylabel('COUNT')
plt.savefig("bronx-crime-month-low.png",bbox_inches='tight')

# %%
#brooklyn
pivot_brooklyn= brooklyn.pivot(index='MONTH', columns='OFNS_DESC', values='COUNT')
#pivot_brooklyn= brooklyn.set_index('HADEVELOPT')
pivot_brooklyn.plot(kind='bar',stacked=True,)
#plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8), title='OFNS_DESC')
plt.legend(loc='upper right', bbox_to_anchor=(1.7, 0.8), title='OFNS_DESC')
plt.title("Months at which Crimes were Lowest")
plt.xlabel('MONTH')
plt.ylabel('COUNT')
plt.savefig("brooklyn-crime-month-low.png",bbox_inches='tight')

# %%
#manhattan
pivot_manhattan= manhattan.pivot(index='MONTH', columns='OFNS_DESC', values='COUNT')
#pivot_manhattan= manhattan.set_index('HADEVELOPT')
pivot_manhattan.plot(kind='bar',stacked=True,)
#plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8), title='OFNS_DESC')
plt.legend(loc='upper right', bbox_to_anchor=(1.7, 0.8), title='OFNS_DESC')
plt.title("Months at which Crimes were Lowest")
plt.xlabel('MONTH')
plt.ylabel('COUNT')
plt.savefig("manhattan-crime-month-low.png",bbox_inches='tight')

# %%
#queens
pivot_queens= queens.pivot(index='MONTH', columns='OFNS_DESC', values='COUNT')
#pivot_queens= queens.set_index('HADEVELOPT')
pivot_queens.plot(kind='bar',stacked=True,)
#plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8), title='OFNS_DESC')
plt.legend(loc='upper right', bbox_to_anchor=(1.7, 0.8), title='OFNS_DESC')
plt.title("Months at which Crimes were Lowest")
plt.xlabel('MONTH')
plt.ylabel('COUNT')
plt.savefig("queens-crime-month-low.png",bbox_inches='tight')

# %%
#staten
pivot_staten= staten.pivot(index='MONTH', columns='OFNS_DESC', values='COUNT')
#pivot_staten= staten.set_index('HADEVELOPT')
pivot_staten.plot(kind='bar',stacked=True,)
#plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8), title='OFNS_DESC')
plt.legend(loc='upper right', bbox_to_anchor=(1.7, 0.8), title='OFNS_DESC')
plt.title("Months at which Crimes were Lowest")
plt.xlabel('MONTH')
plt.ylabel('COUNT')
plt.savefig("staten-crime-month-low.png",bbox_inches='tight')
