# %%
#matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display
# %matplotlib inline
plt.style.use('ggplot')


#load csv
overall = pd.read_csv("overall-crime.csv", header=None,)
overall.columns = ['PRECINCT', 'COUNT']
bronx = pd.read_csv("bronx-crime.csv", header=None,)
bronx.columns = ['PRECINCT', 'COUNT']

brooklyn = pd.read_csv("brooklyn-crime.csv", header=None,)
brooklyn.columns = ['PRECINCT', 'COUNT']

manhattan = pd.read_csv("manhattan-crime.csv", header=None,)
manhattan.columns = ['PRECINCT', 'COUNT']

staten = pd.read_csv("staten-crime.csv", header=None,)
staten.columns = ['PRECINCT', 'COUNT']

queens = pd.read_csv("queens-crime.csv", header=None,)
queens.columns = ['PRECINCT', 'COUNT']

# %%
#kycd & ofnc top 10 
overall=overall.sort_values(by='COUNT')
overall = overall.head(10)
overall.to_csv('bottom-overall.csv')

# %%
#staten
staten = staten.sort_values(by='COUNT')
staten=staten.head(10)
staten.to_csv('bottom-staten.csv')

# %%
#bronx
bronx = bronx.sort_values(by='COUNT')
bronx=bronx.head(10)
bronx.to_csv('bottom-bronx.csv')

# %%
#brooklyn
brooklyn = brooklyn.sort_values(by='COUNT')
brooklyn=brooklyn.head(10)
brooklyn.to_csv('bottom-brooklyn.csv')

# %%
#manhttan
manhattan=manhattan.sort_values(by='COUNT')
manhattan=manhattan.head(10)
manhattan.to_csv('bottom-manhattan.csv')

# %%
#queens
queens=queens.sort_values(by='COUNT')
queens=queens.head(10)
queens.to_csv('bottom-queens.csv')

# %%
#overall
overall = overall.set_index('PRECINCT')
# pivot_overall.plot(kind='bar',stacked=True,)
overall.plot(kind='bar')
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8))
plt.title("Top 10 Precinct with Lowest Crime Rates in NYC")
plt.xlabel('PRECINCT')
plt.ylabel('COUNT')
plt.savefig("crime-precint-wise-low.png",bbox_inches='tight')

# %%
#bronx
# pivot_bronx = bronx.pivot(index='PD_DESC', columns='PD_CD', values='COUNT')
bronx = bronx.set_index('PRECINCT')
bronx.plot(kind='bar',stacked=True,)
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8))
plt.title("Top 10 Precinct with Lowest Crime Rates in Bronx")
plt.xlabel('PRECINCT')
plt.ylabel('COUNT')
plt.savefig("bronx-crime-precinct-wise-low.png",bbox_inches='tight')

# %%
#brooklyn
# pivot_brooklyn = brooklyn.pivot(index='PD_DESC', columns='PD_CD', values='COUNT')
brooklyn = brooklyn.set_index('PRECINCT')
brooklyn.plot(kind='bar',stacked=True,)
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8))
plt.title("Top 10 Precinct with Lowest Crime Rates in Brooklyn")
plt.xlabel('PRECINCT')
plt.ylabel('COUNT')
plt.savefig("brooklyn-crime-precinct-wise-low.png",bbox_inches='tight')

# %%
#manhattan
# pivot_manhattan = manhattan.pivot(index='PD_DESC', columns='PD_CD', values='COUNT')
manhattan = manhattan.set_index('PRECINCT')
manhattan.plot(kind='bar',stacked=True,)
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8))
plt.title("Top 10 Precinct with Lowest Crime Rates in Manhattan")
plt.xlabel('PRECINCT')
plt.ylabel('COUNT')
plt.savefig("manhattan-crime-precinct-wise-low.png",bbox_inches='tight')

# %%
#queens
queens = queens.set_index('PRECINCT')
#pivot_queens = queens.pivot(index='PD_DESC', columns='PD_CD', values='COUNT')
queens.plot(kind='bar',stacked=True,)
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8))
plt.title("Top 10 Precinct with Lowest Crime Rates in NYC")
plt.xlabel('PRECINCT')
plt.ylabel('COUNT')
plt.savefig("queens-crime-precinct-wise-low.png",bbox_inches='tight')

# %%
#staten
staten = staten.set_index('PRECINCT')
# pivot_staten = staten.pivot(index='PD_DESC', columns='PD_CD', values='COUNT')
staten.plot(kind='bar',stacked=True,)
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 0.8))
plt.title("Top 10 Precinct with Lowest Crime Rates in Staten Island")
plt.xlabel('PRECINCT')
plt.ylabel('COUNT')
plt.savefig("staten-crime-low.png",bbox_inches='tight')
